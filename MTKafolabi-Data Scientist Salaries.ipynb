# %% [markdown]
# # DATA SCIENTIST SALARIES
#
# A WORK DONE BY:
# #### AFOLABI, Michael Temitope (MTK AFOLABI)

# %% [markdown]
# ## CASE STUDY
#
# Data science jobs are some of the fastest-growing, most in-demand in technology. Since 2012, Data Scientist roles have increased by 650 percent, and this rise shows no sign of stopping.
#
# The U.S. Bureau of Labor Statistics predicts that the demand for data science skills will increase another 27.9 percent by 2026. And, according to a report from McKinsey, that spells a shortage of between 140,000 and 190,000 people with analytical skills in the U.S. alone—not to mention another 1.5 million managers and analysts who will be required to understand how data analysis drives decision-making.
#
# Data Scientist salaries have also risen with demand; Data Scientists can typically expect to make six figures. Demand also translates into an ability to relocate far more easily—from city to city, and even internationally.

# %% [markdown]
# ### DATA DICTIONARY
#
# THE COLUMN INTERPRETATION
#
# 1. work_year = The year the salary was paid.
# 2. experience_level = The experience level in the job during the year with the following possible values: EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director
# 3. employment_type = The type of employement for the role: PT Part-time FT Full-time CT Contract FL Freelance
# 4. job_title = The role worked in during the year.
# 5. salary = The total gross salary amount paid.
# 6. salary_currency = The currency of the salary paid as an ISO 4217 currency code.
# 7. salaryinusd = The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com).
# 8. employee_residence = Employee's primary country of residence in during the work year as an ISO 3166 country code.
# 9. remote_ratio = The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
# 10. company_location = The country of the employer's main office or contracting branch as an ISO 3166 country code.
# 11. company_size = The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)

# %% [markdown]
# The dataset consists of 12 features with 607 candidate's salary estimated. The features used in the dataset are described below:
#
# | Columns | Description |
# | --- | --- |
# | work_year | The year the salary was paid. |
# | experience_level | The experience level in the job during the year with the following possible values: EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director |
# | employment_type | The type of employement for the role: PT Part-time FT Full-time CT Contract FL Freelance |
# | job_title | The role worked in during the year. |
# | salary | The total gross salary amount paid. |
# | salary_currency | The currency of the salary paid as an ISO 4217 currency code. |
# | salaryinusd | The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com). |
# | employee_residence | Employee's primary country of residence in during the work year as an ISO 3166 country code. |
# | remote_ratio | The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%) |
# | company_location | The country of the employer's main office or contracting branch as an ISO 3166 country code. |
# | company_size | The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large) |

# %%
#the libraries used

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading of the data set

ds_sal = pd.read_csv('ds_salaries.csv')

# %%
ds_sal
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#the first 10 data

ds_sal.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
#used to view the bottom rows of the data set

ds_sal.tail(10)
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 597         597       2022               SE              FT    Data Analyst
# 598         598       2022               MI              FT  Data Scientist
# 599         599       2022               MI              FT  Data Scientist
# 600         600       2022               EN              FT    Data Analyst
# 601         601       2022               EN              FT    Data Analyst
# 602         602       2022               SE              FT   Data Engineer
# 603         603       2022               SE              FT   Data Engineer
# 604         604       2022               SE              FT    Data Analyst
# 605         605       2022               SE              FT    Data Analyst
# 606         606       2022               MI              FT    AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
# Checking missing values

ds_sal.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# used to know the shape attribute

ds_sal.shape
# Out:
# (607, 12)

# %%
ds_sal.shape[0]
# Out:
# 607

# %%
ds_sal.shape[1]
# Out:
# 12

# %%
#used to get the statistical summary of the data (details of dataset)

ds_sal.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
ds_sal['job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
# How the Data looks like

ds_sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# Checking for duplicate values

ds_sal.duplicated().sum()
# Out:
# 0

# %%
# convert abbreviation into precise categories

ds_sal['experience_level']=ds_sal['experience_level'].replace({'EN':'Entry Level', 'EX':'Experienced Level', 
                                                        'MI':'Mid Level', 'SE':'Senior Level'})

ds_sal['remote_ratio']=ds_sal['remote_ratio'].replace({0:'On-site', 50:'Hybrid', 100:'Remote'})

ds_sal['employment_type']=ds_sal['employment_type'].replace({'PT':'Part time', 
                                                     'FT':'Full time', 'CT':'Contract', 'FL':'Freelance'})
ds_sal['company_size']=ds_sal['company_size'].replace({'S':'Small','M':'Medium',
                                                'L':'Large'})

# %%
# Level of Experience

plt.figure(figsize =(15,5))
plt.subplot(1,2,1)
ds_sal['experience_level'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))

plt.subplot(1,2,2)
ds_sal['experience_level'].value_counts().plot(kind = 'pie', autopct = "%.2f")

plt.show()

# %%
# Job titles

plt.figure(figsize = (5,5))
ds_sal['job_title'].value_counts()[:20].plot(kind = 'line', color = 'black', marker = "*")
ds_sal['job_title'].value_counts()[:20].plot(kind = 'bar', color = sns.color_palette('tab10'))
# Out:
# <AxesSubplot:>

# %%
# 1. Univarite Analysis

# Type of Employee

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
ds_sal['employment_type'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Employment_type')
plt.ylabel('Employees')

plt.subplot(1,2,2)
ds_sal['employment_type'].value_counts().plot(kind = 'pie')

plt.show()

# %%
# Employee Residence

plt.figure(figsize = (30,5))
plt.subplot(1,2,1)
ds_sal['employee_residence'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Employee_Residence')
plt.ylabel('Employees')


plt.show()

# %%
# Company Location

plt.figure(figsize = (25,5))
plt.subplot(1,2,1)
ds_sal['company_location'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Company_Location')
plt.ylabel('Employees')

plt.show()

# %%
# Company Size

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
ds_sal['company_size'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Company_Size')
plt.ylabel('Employees')

plt.subplot(1,2,2)
ds_sal['company_size'].value_counts().plot(kind = 'pie')

plt.show()

# %%
# Work Year

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
ds_sal['work_year'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Work_Year')
plt.ylabel('Employees')

plt.subplot(1,2,2)
ds_sal['work_year'].value_counts().plot(kind = 'pie')

plt.show()

# %%
# Salary In USD

plt.figure(figsize = (50,3))
plt.subplot(1,2,1)
ds_sal['salary_in_usd'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Salary_In_Usd')
plt.ylabel('Employees')


plt.show()

# %%
# Remote Ratio

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
ds_sal['remote_ratio'].value_counts().plot(kind = 'bar', color = sns.color_palette('tab10'))
plt.xlabel('Remote_Ratio')
plt.ylabel('Employees')

plt.subplot(1,2,2)
ds_sal['remote_ratio'].value_counts().plot(kind = 'pie')

plt.show()

# %%
ds_sal.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
# Work year analysis with Remote Ratio by Work Year

plt.figure(figsize = (25,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['work_year'],ds_sal['remote_ratio'],hue = ds_sal['remote_ratio'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary in every year by Exprience_level using bar plot and box plot in box plot easily detect the outlier

plt.figure(figsize = (15,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['work_year'],ds_sal['salary_in_usd'],hue = ds_sal['experience_level'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['work_year'],ds_sal['salary_in_usd'], hue = ds_sal['experience_level'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Experience Level Analysis by Job Title

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.barplot(ds_sal['experience_level'],ds_sal['salary_in_usd'], hue = ds_sal['job_title'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['experience_level'], ds_sal['salary_in_usd'], hue = ds_sal['job_title'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Experience Level Analysis by Company Size

plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.barplot(ds_sal['experience_level'],ds_sal['salary_in_usd'], hue = ds_sal['company_size'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['experience_level'], ds_sal['salary_in_usd'], hue = ds_sal['company_size'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Company Loaction Analysis with Experience Level

plt.figure(figsize = (35,7))
plt.subplot(1,2,1)
sns.barplot(ds_sal['experience_level'],ds_sal['salary_in_usd'], hue = ds_sal['company_location'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary Analysis - Salary by work year using bar plot and box plot in box plot easily detect the outlier

plt.figure(figsize = (15,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['work_year'],ds_sal['salary_in_usd'],hue = ds_sal['work_year'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['work_year'],ds_sal['salary_in_usd'], hue = ds_sal['work_year'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary Analysis - Salary by Experience Level using bar plot and box plot in box plot easily detect the outlier

plt.figure(figsize = (15,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['experience_level'],ds_sal['salary_in_usd'],hue = ds_sal['experience_level'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['experience_level'],ds_sal['salary_in_usd'], hue = ds_sal['experience_level'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary Analysis - Salary by Company Size using bar plot and box plot in box plot easily detect the outlier

plt.figure(figsize = (15,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['company_size'],ds_sal['salary_in_usd'],hue = ds_sal['company_size'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['company_size'],ds_sal['salary_in_usd'], hue = ds_sal['company_size'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary Analysis - Salary by Job Title using bar plot and box plot in box plot easily detect the outlier

plt.figure(figsize = (15,5))

plt.subplot(1,2,1)
sns.barplot(ds_sal['job_title'],ds_sal['salary_in_usd'],hue = ds_sal['job_title'])

plt.subplot(1,2,2)
sns.boxplot(ds_sal['job_title'],ds_sal['salary_in_usd'], hue = ds_sal['job_title'])

plt.show()
# Out:
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ICT-CEDARS WORLD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Salary Analysis with Average Salary by Company Location
   
fig, ax = plt.subplots(1,1, figsize=(25,5))
AvgSal_ComLoc = ds_sal.groupby('company_location')['salary_in_usd'].mean().astype(int)
ax=sns.barplot(x=AvgSal_ComLoc.index, y=AvgSal_ComLoc, 
               data=ds_sal, palette=("Blues"))
plt.title('Average Salary By Company Location')
for container in ax.containers:
    ax.bar_label(container)

# %%
# Checked the number of jobs by Employment Type

ds_sal['employment_type'].value_counts()
# Out:
# Full time    588
# Part time     10
# Contract       5
# Freelance      4
# Name: employment_type, dtype: int64

# %%
# Salary Distribution

fig, ax = plt.subplots(1,1, figsize=(10,5))
sns.histplot(x='salary_in_usd', data=ds_sal, ax=ax, kde=True)
plt.title('Salary distribution')
plt.show()
